# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import numpy as np
import math
import networkx as nx

# Define problem variables
n = 14 # number of districts
g = 400 # number of block groups in each district
G = 7047 # total number of block groups
map = [] # block group numbers used to calculate modularity (idk what this looks like)
distribution = [] # tells you which block groups are in each district

# Optimization variables
N = 1000 # number of iterations

modularity_scores = [] # 14x1 vector of modularity scores

# Initial guess
# 1. Divide into 14 districts with g number of block groups in each district
#       a. Initialize distribution matrix/vector
# 2. Calculate initial modularity score 
#       b. Initialize modularity_scores vector

# %% [markdown]
# ## Optimization of Louvain

# %%
# go
for i in N: # total number of times we let louvain go
    for j in n: # iterate over each district
        a = 0
        # 1. Find neighboring block group that will maximize the modularity score
        # 2. Swap
        # 3. Calculate new modularity score
        # 4. Update modularity scores and districts

# End results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # go
# ----> 2 for i in N: # total number of times we let louvain go
#       3     for j in n: # iterate over each district
#       4         a = 0
#
# NameError: name 'N' is not defined

# %% [markdown]
# ## Visualization
